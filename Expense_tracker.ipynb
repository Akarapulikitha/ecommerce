# %% [markdown]
# <a href="https://colab.research.google.com/github/Akarapulikitha/ecommerce/blob/main/Expense_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from datetime import datetime

File_name = "expenses.csv"

# Initialize file if it doesn't exist
if not os.path.exists(File_name):
    df = pd.DataFrame(columns=["Date", "Category", "Amount"])
    df.to_csv(File_name, index=False)


def add_expense(category, amount):
    """Add a new expense entry"""
    date = datetime.today().strftime('%Y-%m-%d')
    new_data = pd.DataFrame([[date, category, amount]],
                            columns=["Date", "Category", "Amount"])
    new_data.to_csv(File_name, mode='a', header=False, index=False)
    print(f"Added: {amount} in {category} on {date}")


def view_expenses():
    """Load and display all expenses"""
    df = pd.read_csv(File_name)
    print("\nAll Expenses:")
    print(df)
    return df


def visualize_expenses():
    """Visualize expenses by category and trend"""
    df = pd.read_csv(File_name)

    # Date column to datetime
    df["Date"] = pd.to_datetime(df["Date"])

    # Expenses by Category
    category_expense = df.groupby("Category")["Amount"].sum()
    category_expense.plot(kind="bar", title="Expenses by Category")
    plt.xlabel("Category")
    plt.ylabel("Total Spent")
    plt.show()

    # Monthly Expense Trend
    df["Month"] = df["Date"].dt.to_period("M")
    monthly_expense = df.groupby("Month")["Amount"].sum()
    monthly_expense.plot(kind="line", marker='o', title="Monthly Expense Trend")
    plt.xlabel("Month")
    plt.ylabel("Total Spent")
    plt.show()

if __name__ == "__main__":
    while True:
        print("\💹 Expense Tracker Menu")
        print("1. Add Expense")
        print("2. View Expenses")
        print("3. Visualize Expenses")
        print("4. Exit")

        choice = input("Enter choice: ")

        if choice == "1":
            category = input(" Enter category (Food/Travel/Shopping/Games): ")
            amount = float(input("Enter amount: "))
            add_expense(category, amount)

        elif choice == "2":
            view_expenses()

        elif choice == "3":
            visualize_expenses()

        elif choice == "4":
            print("Exiting... Goodbye!")
            break

        else:
            print("Invalid choice! Please try again.")
# Out:
# \💹 Expense Tracker Menu
# 1. Add Expense
# 2. View Expenses
# 3. Visualize Expenses
# 4. Exit
# Enter choice: 1
#  Enter category (Food/Travel/Shopping/Games): mango
# Enter amount: 60
# Added: 60.0 in mango on 2025-08-31
# \💹 Expense Tracker Menu
# 1. Add Expense
# 2. View Expenses
# 3. Visualize Expenses
# 4. Exit
# Enter choice: 1
#  Enter category (Food/Travel/Shopping/Games): clothes
# Enter amount: 250
# Added: 250.0 in clothes on 2025-08-31
# \💹 Expense Tracker Menu
# 1. Add Expense
# 2. View Expenses
# 3. Visualize Expenses
# 4. Exit
# Enter choice: 1
#  Enter category (Food/Travel/Shopping/Games): ladhak
# Enter amount: 125
# Added: 125.0 in ladhak on 2025-08-31
# \💹 Expense Tracker Menu
# 1. Add Expense
# 2. View Expenses
# 3. Visualize Expenses
# 4. Exit
# Enter choice: 2
#
# All Expenses:
#          Date Category  Amount
# 0  2025-08-31     food    99.0
# 1  2025-08-31    Mango    60.0
# 2  2025-08-31  Clothes   250.0
# 3  2025-08-31    mango    60.0
# ...
